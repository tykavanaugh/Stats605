# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Week2HWData.xlsx')

# %%
# %matplotlib inline
display(df)
# Out:
#     Data
# 0     57
# 1     86
# 2    150
# 3    152
# 4    155
# 5    170
# 6    170
# 7    173
# 8    175
# 9    175
# 10   180
# 11   182
# 12   182
# 13   187
# 14   190
# 15   195
# 16   195
# 17   195
# 18   200
# 19   202
# 20   208
# 21   210
# 22   210
# 23   211
# 24   229
# 25   244
# 26   247
# 27   247
# 28   265
# 29   268
# 30   280
# 31   290
# 32   290
# 33   305
# 34   308
# 35   313
# 36   314
# 37   325
# 38   326
# 39   330
# 40   369
# 41   405
# 42   415
# 43   442
# 44   490
# 45   520
# 46   567
# 47   572
# 48   572
# 49   590

# %%
plt.hist(df['Data'], bins=5)
plt.xlabel('Bins')
plt.set_xticklabels([115.63,232.89,350.15,467.41,584.67])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-08b1197f1146> in <module>()
#       1 plt.hist(df['Data'], bins=5)
#       2 plt.xlabel('Bins')
# ----> 3 plt.set_xticklabels([115.63,232.89,350.15,467.41,584.67])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_xticklabels'
